# %%
# !pip install torch-geometric==2.2.* torch-scatter torch-sparse
# !pip install pytorch-lightning yacs torchmetrics
# !pip install performer-pytorch
# !pip install tensorboardX
# !pip install ogb
# !pip install wandb
# !pip install git+https://gitlab.com/Xiangyan93/graphdot.git@feature/xy mgktools==2.1.0 scikit-learn==1.4.2
# !pip install git+https://github.com/Xiangyan93/GraphGPS.git@CustomDataset
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 931.6/931.6 kB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 41.6 MB/s eta 0:00:00
# ...

# %%
# Run 5-fold cross-validation using GraphGPS
# GraphGPS (reactants)
# !graphgps_train --cfg_file GPS_regression.yaml --save_dir graphgps --data_path ../../data/luciferase_expression.csv --smiles_columns reactant1 reactant2 --target_columns logv --cross_validation n-fold --nfold 5 --num_folds 10 --seed 0
# GraphGPS-RDKit (reactants)
# !graphgps_train --cfg_file GPS_regression.yaml --save_dir graphgps --data_path ../../data/luciferase_expression.csv --smiles_columns reactant1 reactant2 --target_columns logv --cross_validation n-fold --nfold 5 --num_folds 10 --seed 0 --features_generator rdkit_2d_normalized
# GraphGPS (product)
# !graphgps_train --cfg_file GPS_regression.yaml --save_dir graphgps --data_path ../../data/luciferase_expression.csv --smiles_columns product --target_columns logv --cross_validation n-fold --nfold 5 --num_folds 10 --seed 0
# GraphGPS-RDKit (product)
# !graphgps_train --cfg_file GPS_regression.yaml --save_dir graphgps --data_path ../../data/luciferase_expression.csv --smiles_columns product --target_columns logv --cross_validation n-fold --nfold 5 --num_folds 10 --seed 0 --features_generator rdkit_2d_normalized
